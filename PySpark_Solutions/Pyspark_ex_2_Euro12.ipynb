# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=1658327267f5ae19ab175caf422a085d4f54fefbc24208ff9d2c4b570eef4b08
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType, FloatType
from pyspark.sql.functions import expr, col
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
from pyspark.sql.functions import expr, col, mean

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %%
# !wget -O Euro_2012_stats_TEAM.csv https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv
# Out:
# --2024-04-09 14:57:33--  https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2319 (2.3K) [text/plain]
# Saving to: ‘Euro_2012_stats_TEAM.csv’
#
# Euro_2012_stats_TEA 100%[===================>]   2.26K  --.-KB/s    in 0s
#
# 2024-04-09 14:57:33 (28.7 MB/s) - ‘Euro_2012_stats_TEAM.csv’ saved [2319/2319]

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro12 = spark.read.csv("Euro_2012_stats_TEAM.csv", sep=',', header=True, inferSchema=True)

# %%
euro12.schema
# Out:
# StructType([StructField('Team', StringType(), True), StructField('Goals', IntegerType(), True), StructField('Shots on target', IntegerType(), True), StructField('Shots off target', IntegerType(), True), StructField('Shooting Accuracy', StringType(), True), StructField('% Goals-to-shots', StringType(), True), StructField('Total shots (inc. Blocked)', IntegerType(), True), StructField('Hit Woodwork', IntegerType(), True), StructField('Penalty goals', IntegerType(), True), StructField('Penalties not scored', IntegerType(), True), StructField('Headed goals', IntegerType(), True), StructField('Passes', IntegerType(), True), StructField('Passes completed', IntegerType(), True), StructField('Passing Accuracy', StringType(), True), StructField('Touches', IntegerType(), True), StructField('Crosses', IntegerType(), True), StructField('Dribbles', IntegerType(), True), StructField('Corners Taken', IntegerType(), True), StructField('Tackles', IntegerType(), True), StructField('Clearances', IntegerType(), True), StructField('Interceptions', IntegerType(), True), StructField('Clearances off line', IntegerType(), True), StructField('Clean Sheets', IntegerType(), True), StructField('Blocks', IntegerType(), True), StructField('Goals conceded', IntegerType(), True), StructField('Saves made', IntegerType(), True), StructField('Saves-to-shots ratio', StringType(), True), StructField('Fouls Won', IntegerType(), True), StructField('Fouls Conceded', IntegerType(), True), StructField('Offsides', IntegerType(), True), StructField('Yellow Cards', IntegerType(), True), StructField('Red Cards', IntegerType(), True), StructField('Subs on', IntegerType(), True), StructField('Subs off', IntegerType(), True), StructField('Players Used', IntegerType(), True)])

# %%
euro12.show(10)
# Out:
# +--------------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |          Team|Goals|Shots on target|Shots off target|Shooting Accuracy|% Goals-to-shots|Total shots (inc. Blocked)|Hit Woodwork|Penalty goals|Penalties not scored|Headed goals|Passes|Passes completed|Passing Accuracy|Touches|Crosses|Dribbles|Corners Taken|Tackles|Clearances|Interceptions|Clearances off line|Clean Sheets|Blocks|Goals conceded|Saves made|Saves-to-shots ratio|Fouls Won|Fouls Conceded|Offsides|Yellow Cards|Red Cards|Subs on|Subs off|Players Used|
# +--------------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |       Croatia|    4|             13|              12|            51.9%|           16.0%|                        32|           0|            0|                   0|           2|  1076|             828|           76.9%|   1706|     60|      42|           14|     49|        83|           56|               NULL|           0|    10|             3|        13|               81.3%|       41|            62|       2|           9|        0|      9|       9|          16|
# |Czech Republic|    4|             13|              18|            41.9%|           12.9%|                        39|           0|            0|                   0|           0|  1565|            1223|           78.1%|   2358|     46|      68|           21|     62|        98|           37|                  2|           1|    10|             6|         9|               60.1%|       53|            73|       8|           7|        0|     11|      11|          19|
# |       Denmark|    4|             10|              10|            50.0%|           20.0%|                        27|           1|            0|                   0|           3|  1298|            1082|           83.3%|   1873|     43|      32|           16|     40|        61|           59|                  0|           1|    10|             5|        10|               66.7%|       25|            38|       8|           4|        0|      7|       7|          15|
# |       England|    5|             11|              18|            50.0%|           17.2%|                        40|           0|            0|                   0|           3|  1488|            1200|           80.6%|   2440|     58|      60|           16|     86|       106|           72|                  1|           2|    29|             3|        22|               88.1%|       43|            45|       6|           5|        0|     11|      11|          16|
# |        France|    3|             22|              24|            37.9%|            6.5%|                        65|           1|            0|                   0|           0|  2066|            1803|           87.2%|   2909|     55|      76|           28|     71|        76|           58|                  0|           1|     7|             5|         6|               54.6%|       36|            51|       5|           6|        0|     11|      11|          19|
# |       Germany|   10|             32|              32|            47.8%|           15.6%|                        80|           2|            1|                   0|           2|  2774|            2427|           87.4%|   3761|    101|      60|           35|     91|        73|           69|                  0|           1|    11|             6|        10|               62.6%|       63|            49|      12|           4|        0|     15|      15|          17|
# |        Greece|    5|              8|              18|            30.7%|           19.2%|                        32|           1|            1|                   1|           0|  1187|             911|           76.7%|   2016|     52|      53|           10|     65|       123|           87|                  0|           1|    23|             7|        13|               65.1%|       67|            48|      12|           9|        1|     12|      12|          20|
# |         Italy|    6|             34|              45|            43.0%|            7.5%|                       110|           2|            0|                   0|           2|  3016|            2531|           83.9%|   4363|     75|      75|           30|     98|       137|          136|                  1|           2|    18|             7|        20|               74.1%|      101|            89|      16|          16|        0|     18|      18|          19|
# |   Netherlands|    2|             12|              36|            25.0%|            4.1%|                        60|           2|            0|                   0|           0|  1556|            1381|           88.7%|   2163|     50|      49|           22|     34|        41|           41|                  0|           0|     9|             5|        12|               70.6%|       35|            30|       3|           5|        0|      7|       7|          15|
# |        Poland|    2|             15|              23|            39.4%|            5.2%|                        48|           0|            0|                   0|           1|  1059|             852|           80.4%|   1724|     55|      39|           14|     67|        87|           62|                  0|           0|     8|             3|         6|               66.7%|       48|            56|       3|           7|        1|      7|       7|          17|
# +--------------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# only showing top 10 rows

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12.select(col('Goals')).show()
# Out:
# +-----+
# |Goals|
# +-----+
# |    4|
# |    4|
# |    4|
# |    5|
# |    3|
# |   10|
# |    5|
# |    6|
# |    2|
# |    2|
# |    6|
# |    1|
# |    5|
# |   12|
# |    5|
# |    2|
# +-----+

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro12.select(col('Team')).distinct().count()
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
euro12.columns
# Out:
# ['Team',
#  'Goals',
#  'Shots on target',
#  'Shots off target',
#  'Shooting Accuracy',
#  '% Goals-to-shots',
#  'Total shots (inc. Blocked)',
#  'Hit Woodwork',
#  'Penalty goals',
#  'Penalties not scored',
#  'Headed goals',
#  'Passes',
#  'Passes completed',
#  'Passing Accuracy',
#  'Touches',
#  'Crosses',
#  'Dribbles',
#  'Corners Taken',
#  'Tackles',
#  'Clearances',
#  'Interceptions',
#  'Clearances off line',
#  'Clean Sheets',
#  'Blocks',
#  'Goals conceded',
#  'Saves made',
#  'Saves-to-shots ratio',
#  'Fouls Won',
#  'Fouls Conceded',
#  'Offsides',
#  'Yellow Cards',
#  'Red Cards',
#  'Subs on',
#  'Subs off',
#  'Players Used']

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12.select('Team', 'Yellow Cards', 'Red Cards')

# %%
discipline.show()
# Out:
# +-------------------+------------+---------+
# |               Team|Yellow Cards|Red Cards|
# +-------------------+------------+---------+
# |            Croatia|           9|        0|
# |     Czech Republic|           7|        0|
# |            Denmark|           4|        0|
# |            England|           5|        0|
# |             France|           6|        0|
# |            Germany|           4|        0|
# |             Greece|           9|        1|
# |              Italy|          16|        0|
# |        Netherlands|           5|        0|
# |             Poland|           7|        1|
# |           Portugal|          12|        0|
# |Republic of Ireland|           6|        1|
# |             Russia|           6|        0|
# |              Spain|          11|        0|
# |             Sweden|           7|        0|
# |            Ukraine|           5|        0|
# +-------------------+------------+---------+

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.orderBy('Red Cards', 'Yellow Cards', ascending=False).show()
# Out:
# +-------------------+------------+---------+
# |               Team|Yellow Cards|Red Cards|
# +-------------------+------------+---------+
# |             Greece|           9|        1|
# |             Poland|           7|        1|
# |Republic of Ireland|           6|        1|
# |              Italy|          16|        0|
# |           Portugal|          12|        0|
# |              Spain|          11|        0|
# |            Croatia|           9|        0|
# |     Czech Republic|           7|        0|
# |             Sweden|           7|        0|
# |             France|           6|        0|
# |             Russia|           6|        0|
# |            England|           5|        0|
# |        Netherlands|           5|        0|
# |            Ukraine|           5|        0|
# |            Denmark|           4|        0|
# |            Germany|           4|        0|
# +-------------------+------------+---------+

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
discipline.select(mean(col('Yellow Cards'))).show()
# Out:
# +-----------------+
# |avg(Yellow Cards)|
# +-----------------+
# |           7.4375|
# +-----------------+

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12.filter(col('Goals')>6).show()
# Out:
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |   Team|Goals|Shots on target|Shots off target|Shooting Accuracy|% Goals-to-shots|Total shots (inc. Blocked)|Hit Woodwork|Penalty goals|Penalties not scored|Headed goals|Passes|Passes completed|Passing Accuracy|Touches|Crosses|Dribbles|Corners Taken|Tackles|Clearances|Interceptions|Clearances off line|Clean Sheets|Blocks|Goals conceded|Saves made|Saves-to-shots ratio|Fouls Won|Fouls Conceded|Offsides|Yellow Cards|Red Cards|Subs on|Subs off|Players Used|
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |Germany|   10|             32|              32|            47.8%|           15.6%|                        80|           2|            1|                   0|           2|  2774|            2427|           87.4%|   3761|    101|      60|           35|     91|        73|           69|                  0|           1|    11|             6|        10|               62.6%|       63|            49|      12|           4|        0|     15|      15|          17|
# |  Spain|   12|             42|              33|            55.9%|           16.0%|                       100|           0|            1|                   0|           2|  4317|            3820|           88.4%|   5585|     69|     106|           44|    122|       102|           79|                  0|           5|     8|             1|        15|               93.8%|      102|            83|      19|          11|        0|     17|      17|          18|
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
euro12.filter(col('Team').startswith('G')).show()
# Out:
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |   Team|Goals|Shots on target|Shots off target|Shooting Accuracy|% Goals-to-shots|Total shots (inc. Blocked)|Hit Woodwork|Penalty goals|Penalties not scored|Headed goals|Passes|Passes completed|Passing Accuracy|Touches|Crosses|Dribbles|Corners Taken|Tackles|Clearances|Interceptions|Clearances off line|Clean Sheets|Blocks|Goals conceded|Saves made|Saves-to-shots ratio|Fouls Won|Fouls Conceded|Offsides|Yellow Cards|Red Cards|Subs on|Subs off|Players Used|
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+
# |Germany|   10|             32|              32|            47.8%|           15.6%|                        80|           2|            1|                   0|           2|  2774|            2427|           87.4%|   3761|    101|      60|           35|     91|        73|           69|                  0|           1|    11|             6|        10|               62.6%|       63|            49|      12|           4|        0|     15|      15|          17|
# | Greece|    5|              8|              18|            30.7%|           19.2%|                        32|           1|            1|                   1|           0|  1187|             911|           76.7%|   2016|     52|      53|           10|     65|       123|           87|                  0|           1|    23|             7|        13|               65.1%|       67|            48|      12|           9|        1|     12|      12|          20|
# +-------+-----+---------------+----------------+-----------------+----------------+--------------------------+------------+-------------+--------------------+------------+------+----------------+----------------+-------+-------+--------+-------------+-------+----------+-------------+-------------------+------------+------+--------------+----------+--------------------+---------+--------------+--------+------------+---------+-------+--------+------------+

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
columns = euro12.columns
columns
# Out:
# ['Team',
#  'Goals',
#  'Shots on target',
#  'Shots off target',
#  'Shooting Accuracy',
#  '% Goals-to-shots',
#  'Total shots (inc. Blocked)',
#  'Hit Woodwork',
#  'Penalty goals',
#  'Penalties not scored',
#  'Headed goals',
#  'Passes',
#  'Passes completed',
#  'Passing Accuracy',
#  'Touches',
#  'Crosses',
#  'Dribbles',
#  'Corners Taken',
#  'Tackles',
#  'Clearances',
#  'Interceptions',
#  'Clearances off line',
#  'Clean Sheets',
#  'Blocks',
#  'Goals conceded',
#  'Saves made',
#  'Saves-to-shots ratio',
#  'Fouls Won',
#  'Fouls Conceded',
#  'Offsides',
#  'Yellow Cards',
#  'Red Cards',
#  'Subs on',
#  'Subs off',
#  'Players Used']

# %%
euro12.select([col('`' + c + '`') for c in euro12.columns[0:7]]).show()
# Out:
# +-------------------+-----+---------------+----------------+-----------------+----------------+--------------------------+
# |               Team|Goals|Shots on target|Shots off target|Shooting Accuracy|% Goals-to-shots|Total shots (inc. Blocked)|
# +-------------------+-----+---------------+----------------+-----------------+----------------+--------------------------+
# |            Croatia|    4|             13|              12|            51.9%|           16.0%|                        32|
# |     Czech Republic|    4|             13|              18|            41.9%|           12.9%|                        39|
# |            Denmark|    4|             10|              10|            50.0%|           20.0%|                        27|
# |            England|    5|             11|              18|            50.0%|           17.2%|                        40|
# |             France|    3|             22|              24|            37.9%|            6.5%|                        65|
# |            Germany|   10|             32|              32|            47.8%|           15.6%|                        80|
# |             Greece|    5|              8|              18|            30.7%|           19.2%|                        32|
# |              Italy|    6|             34|              45|            43.0%|            7.5%|                       110|
# |        Netherlands|    2|             12|              36|            25.0%|            4.1%|                        60|
# |             Poland|    2|             15|              23|            39.4%|            5.2%|                        48|
# |           Portugal|    6|             22|              42|            34.3%|            9.3%|                        82|
# |Republic of Ireland|    1|              7|              12|            36.8%|            5.2%|                        28|
# |             Russia|    5|              9|              31|            22.5%|           12.5%|                        59|
# |              Spain|   12|             42|              33|            55.9%|           16.0%|                       100|
# |             Sweden|    5|             17|              19|            47.2%|           13.8%|                        39|
# |            Ukraine|    2|              7|              26|            21.2%|            6.0%|                        38|
# +-------------------+-----+---------------+----------------+-----------------+----------------+--------------------------+

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro12.select([col('`' + c + '`')  for c in euro12.columns[-3:]]).show()
# Out:
# +-------+--------+------------+
# |Subs on|Subs off|Players Used|
# +-------+--------+------------+
# |      9|       9|          16|
# |     11|      11|          19|
# |      7|       7|          15|
# |     11|      11|          16|
# |     11|      11|          19|
# |     15|      15|          17|
# |     12|      12|          20|
# |     18|      18|          19|
# |      7|       7|          15|
# |      7|       7|          17|
# |     14|      14|          16|
# |     10|      10|          17|
# |      7|       7|          16|
# |     17|      17|          18|
# |      9|       9|          18|
# |      9|       9|          18|
# +-------+--------+------------+

# %%
euro12.columns[-3:]
# Out:
# ['Subs on', 'Subs off', 'Players Used']

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.select(col('Shooting Accuracy'), col('Team')).filter(col('Team').isin('England', 'Italy', 'Russia')).show()
# Out:
# +-----------------+-------+
# |Shooting Accuracy|   Team|
# +-----------------+-------+
# |            50.0%|England|
# |            43.0%|  Italy|
# |            22.5%| Russia|
# +-----------------+-------+
