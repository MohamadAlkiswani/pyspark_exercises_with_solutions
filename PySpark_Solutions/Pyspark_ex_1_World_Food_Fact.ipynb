# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %%
# !wget -O food.zip https://storage.googleapis.com/kaggle-data-sets/20/4275/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240405%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240405T124027Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Out:
# /bin/bash: line 1: X-Goog-Expires=259200: command not found
# /bin/bash: line 1: X-Goog-Signature=...: command not found
# /bin/bash: line 1: X-Goog-SignedHeaders=host: command not found
# /bin/bash: line 1: X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240405%2Fauto%2Fstorage%2Fgoog4_request: command not found
# /bin/bash: line 1: X-Goog-Date=20240405T124027Z: command not found
# --2024-04-05 12:41:25--  https://storage.googleapis.com/kaggle-data-sets/20/4275/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.8.207, 173.194.174.207, 74.125.23.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.8.207|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2024-04-05 12:41:25 ERROR 400: Bad Request.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %% [markdown]
# ### Step 4. See the first 5 entries

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?
