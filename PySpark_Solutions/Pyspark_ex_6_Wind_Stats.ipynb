# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
from pyspark.sql.types import IntegerType, FloatType
from pyspark.sql.functions import expr, col, mean, when, sum, count, desc, min, max
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %%
# !wget -O wind.data https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data
# Out:
# --2024-04-12 12:01:10--  https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 532576 (520K) [text/plain]
# Saving to: ‘wind.data’
#
# wind.data           100%[===================>] 520.09K  --.-KB/s    in 0.04s
#
# 2024-04-12 12:01:11 (13.6 MB/s) - ‘wind.data’ saved [532576/532576]

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = spark.read.csv('wind.data', sep="   ", header=True, inferSchema=True)
data.show()
# Out:
# +--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+
# |            Yr Mo Dy|                 RPT| VAL| ROS| KIL| SHA| BIR| DUB| CLA| MUL| CLO| BEL| MAL|
# +--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+
# |61  1  1 15.04 14...|NaN  9.87 13.67 1...|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |      61  1  2 14.71|NaN 10.83  6.50 1...|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  3 18.50 16...|NaN  8.50  7.67 1...|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  4 10.58  6...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  5 13.33 13...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  6 13.21  8...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  7 13.50 14...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  8 10.96  9...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1  9 12.58 10...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 10 13.37 11...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 11 10.58  9...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 12 19.75 12...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 13  9.92  3...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 14  9.04  5...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 15 12.04  9...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 16 16.42 11...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 17 17.75 14...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 18 19.83 12...|NaN 10.29 17.83 1...|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 19  4.92  3...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# |61  1 20  9.59 11...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|
# +--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+
# only showing top 20 rows

# %%
wind_data = spark.read.text("wind.data")

# %%
from pyspark.sql.functions import split

split_data = wind_data.select(split(wind_data.value, '\s+').alias('data'))
split_data.show()
# Out:
# +--------------------+
# |                data|
# +--------------------+
# |                  []|
# |[Yr, Mo, Dy, RPT,...|
# |[61, 1, 1, 15.04,...|
# |[61, 1, 2, 14.71,...|
# |[61, 1, 3, 18.50,...|
# |[61, 1, 4, 10.58,...|
# |[61, 1, 5, 13.33,...|
# |[61, 1, 6, 13.21,...|
# |[61, 1, 7, 13.50,...|
# |[61, 1, 8, 10.96,...|
# |[61, 1, 9, 12.58,...|
# |[61, 1, 10, 13.37...|
# |[61, 1, 11, 10.58...|
# |[61, 1, 12, 19.75...|
# |[61, 1, 13, 9.92,...|
# |[61, 1, 14, 9.04,...|
# |[61, 1, 15, 12.04...|
# |[61, 1, 16, 16.42...|
# |[61, 1, 17, 17.75...|
# |[61, 1, 18, 19.83...|
# +--------------------+
# only showing top 20 rows

# %%
split_data.data
# Out:
# Column<'data'>

# %%
@F.udf("string to row", F.ArrayType(F.StringType()))
def string_to_row(data):
    # Extract date (Yr, Mo, Dy) and wind data for each location

    date = F.to_date(F.concat(year, F.lit('-'), month, F.lit('-'), day), 'yyyy-MM-dd')
    wind_data = data[3:]
    return [date] + wind_data
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-28-04e4abfd0f0a> in <cell line: 1>()
#       1 @F.udf("string to row", F.ArrayType(F.StringType()))
# ----> 2 def string_to_row(data):
#       3     # Extract date (Yr, Mo, Dy) and wind data for each location
#       4     year, month, day = data[0:3]
#       5     date = F.to_date(F.concat(year, F.lit('-'), month, F.lit('-'), day), 'yyyy-MM-dd')
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _create_py_udf(f, returnType, useArrow)
#     147             )
#     148
# --> 149     return _create_udf(f, returnType, eval_type)
#     150
#     151
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _create_udf(f, returnType, evalType, name, deterministic)
#      82         f, returnType=returnType, name=name, evalType=evalType, deterministic=deterministic
#      83     )
# ---> 84     return udf_obj._wrapped()
#      85
#      86
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _wrapped(self)
#     431
#     432         wrapper.func = self.func  # type: ignore[attr-defined]
# --> 433         wrapper.returnType = self.returnType  # type: ignore[attr-defined]
#     434         wrapper.evalType = self.evalType  # type: ignore[attr-defined]
#     435         wrapper.deterministic = self.deterministic  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in returnType(self)
#     212                 self._returnType_placeholder = self._returnType
#     213             else:
# --> 214                 self._returnType_placeholder = _parse_datatype_string(self._returnType)
#     215
#     216         if (
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in _parse_datatype_string(s)
#    1317                 return from_ddl_datatype("struct<%s>" % s.strip())
#    1318             except BaseException:
# -> 1319                 raise e
#    1320
#    1321
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in _parse_datatype_string(s)
#    1307     try:
#    1308         # DDL format, "fieldname datatype, fieldname datatype".
# -> 1309         return from_ddl_schema(s)
#    1310     except Exception as e:
#    1311         try:
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in from_ddl_schema(type_str)
#    1295     def from_ddl_schema(type_str: str) -> DataType:
#    1296         return _parse_datatype_json_string(
# -> 1297             cast(JVMView, sc._jvm).org.apache.spark.sql.types.StructType.fromDDL(type_str).json()
#    1298         )
#    1299
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# ParseException:
# [PARSE_SYNTAX_ERROR] Syntax error at or near 'row': extra input 'row'.(line 1, pos 10)
#
# == SQL ==
# string to row
# ----------^^^

# %%
# Out:
# Column<'substring(data, 0, 3)'>

# %%
row_data = split_data.select(string_to_row(split_data.data).alias("row"))
row_data
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-22-4b0fa02e4eca> in <cell line: 1>()
#       1 @F.udf("string to row", F.ArrayType(F.StringType()))
# ----> 2 def string_to_row(data):
#       3     # Extract date (Yr, Mo, Dy) and wind data for each location
#       4     year, month, day = data[0:3]
#       5     date = F.to_date(F.concat(year, F.lit('-'), month, F.lit('-'), day), 'yyyy-MM-dd')
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _create_py_udf(f, returnType, useArrow)
#     147             )
#     148
# --> 149     return _create_udf(f, returnType, eval_type)
#     150
#     151
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _create_udf(f, returnType, evalType, name, deterministic)
#      82         f, returnType=returnType, name=name, evalType=evalType, deterministic=deterministic
#      83     )
# ---> 84     return udf_obj._wrapped()
#      85
#      86
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in _wrapped(self)
#     431
#     432         wrapper.func = self.func  # type: ignore[attr-defined]
# --> 433         wrapper.returnType = self.returnType  # type: ignore[attr-defined]
#     434         wrapper.evalType = self.evalType  # type: ignore[attr-defined]
#     435         wrapper.deterministic = self.deterministic  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/udf.py in returnType(self)
#     212                 self._returnType_placeholder = self._returnType
#     213             else:
# --> 214                 self._returnType_placeholder = _parse_datatype_string(self._returnType)
#     215
#     216         if (
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in _parse_datatype_string(s)
#    1317                 return from_ddl_datatype("struct<%s>" % s.strip())
#    1318             except BaseException:
# -> 1319                 raise e
#    1320
#    1321
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in _parse_datatype_string(s)
#    1307     try:
#    1308         # DDL format, "fieldname datatype, fieldname datatype".
# -> 1309         return from_ddl_schema(s)
#    1310     except Exception as e:
#    1311         try:
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/types.py in from_ddl_schema(type_str)
#    1295     def from_ddl_schema(type_str: str) -> DataType:
#    1296         return _parse_datatype_json_string(
# -> 1297             cast(JVMView, sc._jvm).org.apache.spark.sql.types.StructType.fromDDL(type_str).json()
#    1298         )
#    1299
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# ParseException:
# [PARSE_SYNTAX_ERROR] Syntax error at or near 'row': extra input 'row'.(line 1, pos 10)
#
# == SQL ==
# string to row
# ----------^^^

# %%
df.show()
# Out:
# +---+----+---+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# | Yr|  Mo| Dy| RPT|  VAL|  ROS|  KIL|  SHA|  BIR|  DUB|  CLA|  MUL|  CLO|  BEL|  MAL|
# +---+----+---+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# | 61|NULL|  1|NULL|  1.0|15.04|14.96|13.17| NULL| 9.29| NULL| NULL|  NaN| NULL| 9.87|
# | 61|NULL|  1|NULL|  2.0|14.71| NULL| NULL|  NaN|10.83| NULL|  6.5|12.62| NULL| 7.67|
# | 61|NULL|  1|NULL|  3.0| 18.5|16.88|12.33|10.13|11.17| NULL| 6.17|11.25| NULL| NULL|
# | 61|NULL|  1|NULL|  4.0|10.58| NULL| 6.63|11.75| NULL| 4.58| NULL| 4.54| NULL| 2.88|
# | 61|NULL|  1|NULL|  5.0|13.33|13.25|11.42| NULL| 6.17|10.71| NULL| 8.21|11.92| NULL|
# | 61|NULL|  1|NULL|  6.0|13.21| NULL| 8.12| NULL| 9.96| NULL| 6.67| NULL| 5.37| NULL|
# | 61|NULL|  1|NULL|  7.0| 13.5|14.29| NULL|  9.5| NULL| 4.96|12.29| NULL| 8.33| NULL|
# | 61|NULL|  1|NULL|  8.0|10.96| NULL| 9.75| NULL| 7.62| NULL| 5.91| NULL| 9.62| NULL|
# | 61|NULL|  1|NULL|  9.0|12.58|10.83| 10.0| NULL| 4.75|10.37| NULL| 6.79| NULL| 8.04|
# | 61|NULL|  1|10.0|13.37|11.12| 19.5| NULL| 8.33| NULL| 9.71| NULL| 6.54|11.42| NULL|
# | 61|NULL|  1|11.0|10.58| NULL| 9.87| NULL| 8.42| NULL| 2.79| NULL| 8.71| NULL| 7.25|
# | 61|NULL|  1|12.0|19.75|12.08| 18.5|10.54|10.29| NULL| 9.46|15.54| 11.5|10.37|14.58|
# | 61|NULL|  1|13.0| NULL| 9.92| NULL| 3.54| NULL| 8.46| NULL| 2.96| NULL| 2.29| NULL|
# | 61|NULL|  1|14.0| NULL| 9.04| NULL| 5.66| NULL| 7.08| NULL| 0.67| NULL| 2.71| NULL|
# | 61|NULL|  1|15.0|12.04| NULL| 9.67|11.75| NULL| 2.37| NULL| 7.38| NULL| 3.13| NULL|
# | 61|NULL|  1|16.0|16.42|11.25|15.67| NULL| 4.71|11.34| NULL| 6.92| NULL| 9.25| NULL|
# | 61|NULL|  1|17.0|17.75|14.37|17.33|10.13|13.96|13.37|13.42|11.04| NULL| 8.71|11.38|
# | 61|NULL|  1|18.0|19.83|12.04|20.79|18.54| NULL| NULL|  NaN|10.29|17.83|11.38|14.67|
# | 61|NULL|  1|19.0| NULL| 4.92| NULL| 3.42| NULL| 7.29| NULL| 1.04| NULL| 3.67| NULL|
# | 61|NULL|  1|20.0| NULL| 9.59|11.83| NULL| 7.96| NULL| 1.58| NULL| 7.92| NULL|  5.0|
# +---+----+---+----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+
# only showing top 20 rows

# %%
data = data.withColumn("date", F.to_date(F.concat_ws('-', col('Yr'), data.Mo,data.Dy)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-87866ad92885> in <cell line: 1>()
# ----> 1 data = data.withColumn("date", F.to_date(F.concat_ws('-', data.Yr, data.Mo,data.Dy)))
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in __getattr__(self, name)
#    3125         """
#    3126         if name not in self.columns:
# -> 3127             raise AttributeError(
#    3128                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    3129             )
#
# AttributeError: 'DataFrame' object has no attribute 'Yr'

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
